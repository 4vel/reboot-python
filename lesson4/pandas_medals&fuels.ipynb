# %% [markdown]
# # Pandas и присоединение таблиц

# %%
import pandas as pd
import os

# %%
# Прописываем пути к файлам
bronzefpth = os.path.join('data','medals','Bronze.csv')
silverfpth = os.path.join('data','medals','Silver.csv')
goldfpth = os.path.join('data','medals','Gold.csv')
# Подгружаем CSV
bronze = pd.read_csv(bronzefpth).head(5)
silver = pd.read_csv(silverfpth).head(5)
gold = pd.read_csv(goldfpth).head(5)
gold
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-23ae989eb520> in <module>
#       4 goldfpth = os.path.join('data','medals','Gold.csv')
#       5 # Подгружаем CSV
# ----> 6 bronze = pd.read_csv(bronzefpth).head(5)
#       7 silver = pd.read_csv(silverfpth).head(5)
#       8 gold = pd.read_csv(goldfpth).head(5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/medals/Bronze.csv'

# %%
silver
# Out:
#    NOC         Country   Total
# 0  USA   United States  1195.0
# 1  URS    Soviet Union   627.0
# 2  GBR  United Kingdom   591.0
# 3  FRA          France   461.0
# 4  GER         Germany   350.0

# %%
bronze
# Out:
#    NOC         Country   Total
# 0  USA   United States  1052.0
# 1  URS    Soviet Union   584.0
# 2  GBR  United Kingdom   505.0
# 3  FRA          France   475.0
# 4  GER         Germany   454.0

# %%
medals = gold.copy()

# %%
medals
# Out:
#    NOC         Country   Total
# 0  USA   United States  2088.0
# 1  URS    Soviet Union   838.0
# 2  GBR  United Kingdom   498.0
# 3  FRA          France   378.0
# 4  GER         Germany   407.0

# %%
new_labels = ['NOC', 'Country', 'Gold']
medals.columns = new_labels
medals['Silver'] = silver['Total']
medals['Bronze'] = bronze['Total']

# %%
medals.head()
# Out:
#    NOC         Country    Gold  Silver  Bronze
# 0  USA   United States  2088.0  1195.0  1052.0
# 1  URS    Soviet Union   838.0   627.0   584.0
# 2  GBR  United Kingdom   498.0   591.0   505.0
# 3  FRA          France   378.0   461.0   475.0
# 4  GER         Germany   407.0   350.0   454.0

# %%
# Когда мы хотим слить несколько табиц с одинаковыми колонками в одну большую (по вертикали)
medals_dict = {'gold': goldfpth, 'silver': silverfpth,'bronze':bronzefpth}

# %%
medals_dict
# Out:
# {'gold': 'data/medals/Gold.csv',
#  'silver': 'data/medals/Silver.csv',
#  'bronze': 'data/medals/Bronze.csv'}

# %%
# Можно использовать метод df.append()
# !!! Важно, что он работает не так как append в списках, то есть не inplace
medals_df = pd.DataFrame()

# %%
for medal, fpth in medals_dict.items():
    df_temp = pd.read_csv(fpth)
    df_temp['medal'] = medal
    medals_df = medals_df.append(df_temp)

# %%
medals_df
# Out:
#      NOC               Country   Total   medal
# 0    USA         United States  2088.0    gold
# 1    URS          Soviet Union   838.0    gold
# 2    GBR        United Kingdom   498.0    gold
# 3    FRA                France   378.0    gold
# 4    GER               Germany   407.0    gold
# ..   ...                   ...     ...     ...
# 133  SEN               Senegal     NaN  bronze
# 134  SUD                 Sudan     NaN  bronze
# 135  TGA                 Tonga     NaN  bronze
# 136  BDI               Burundi     NaN  bronze
# 137  UAE  United Arab Emirates     NaN  bronze
#
# [414 rows x 4 columns]

# %% [markdown]
# # Практическая часть

# %%
# Даны 3 таблицы
medalists = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - ALL MEDALISTS.tsv',
                        sep='\t', skiprows=4)
editions = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - EDITIONS.tsv', sep='\t')
countries = pd.read_csv('data/Summer Olympic medalists 1896 to 2008 - IOC COUNTRY CODES.csv')

# %%
# countries.head(3)
# editions.head(3)
# medalists.head(3)

# %%
# Определите гендерное распределение (в процентах) медалистов по странам по годам 
# Выведите результаты в виде таблицы вместе с полем ISO code
#----- Ваш код здесь ----

# %% [markdown]
# # Немного про Pandas & Excel

# %%
# Сохраним medals_df в файл excel
medals_df.to_excel('medals.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c31bd5ef97a> in <module>
#       1 # Сохраним medals_df в файл excel
# ----> 2 medals_df.to_excel('medals.xlsx', index=False)
#
# NameError: name 'medals_df' is not defined

# %%
# Если в excel - файле только один лист, или нужен только первый
df = pd.read_excel('medals.xlsx')
df.head()
# Out:
#    NOC         Country   Total medal
# 0  USA   United States  2088.0  gold
# 1  URS    Soviet Union   838.0  gold
# 2  GBR  United Kingdom   498.0  gold
# 3  FRA          France   378.0  gold
# 4  GER         Germany   407.0  gold

# %%
# Если нужно считать несколько листов из файла, то 
# можно использовать pd.read_excel c параметром sheet_name 
xls = pd.ExcelFile('medals.xlsx')
xls.sheet_names
# Out:
# ['Лист1', 'Лист3', 'Лист2']

# %%
medals_from_excel = pd.DataFrame()
for sheet_name in xls.sheet_names:
    temp_df = pd.read_excel('medals.xlsx', sheet_name=sheet_name)
    medals_from_excel= medals_from_excel.append(temp_df)

# medals_from_excel

# %% [markdown]
# ### Как сохранить DataFrame в ексель на разных листах?

# %%
# Создаем файл
writer = pd.ExcelWriter('medal_on_sheets.xlsx', engine='xlsxwriter')
# Записываем на листы
gold.to_excel(writer, sheet_name='gold', index=False)
silver.to_excel(writer, sheet_name='silver', index=False)
bronze.to_excel(writer, sheet_name='bronze', index=False)
# Сохраняем и закрвыаем 
writer.save()

# %%
# Или так c помощью менеджера контекста with
with pd.ExcelWriter('medal_on_sheets.xlsx', engine='xlsxwriter') as writer:
    for i, tab in enumerate([gold,silver,bronze]):
        tab.to_excel(writer, sheet_name=str(i), index=False)

# %% [markdown]
# # Практическая часть

# %%
# Сохраните DataFrame medalists в файл medalists.xlsx
# В этом файле данные по каждой стране должны быть на отдельном листе
#----- Ваш код здесь ----

# %% [markdown]
# # Pandas & ...

# %%
import pandas as pd
import requests
from tqdm.auto import tqdm

# %%
headers = {'X-Requested-With': 'XMLHttpRequest'}
payload = ({'region':'77'})
url = 'http://www.rosneft-azs.ru/map_search'
r = requests.post(url, data=payload, headers=headers)
res = r.json()

# %%
stations = res['stations']

# %%
url = 'http://www.rosneft-azs.ru/map_search'
url
# Out:
# 'http://www.rosneft-azs.ru/map_search'

# %%
# Формируем словарь со списками для колонок таблицы
# adict = {'Azs':[],'Address' :[],'Price92':[],'Price95':[]}

# %%
from collections import defaultdict

# %%
adict = defaultdict(list)

# %%
# Заполняем списки с помощью цикла
for station in tqdm(stations):     
    adict['Azs'].append(station['id'])
    adict['Address'].append(station['address'])
    adict['Region_code'].append(station['region_code'])
    for d in station['price']:
        if d['type'] == 92:
            adict['Price92'].append(d['price'])
        elif d['type'] == 95:
            adict['Price95'].append(d['price'])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2171.0), HTML(value='')))

# %%
rn = pd.DataFrame.from_dict(adict)
rn.head()
# Out:
#      Azs                                            Address  Region_code  \
# 0  58520  Ростовская обл., Мясниковский р-н, п. Чалтырь,...           61
# 1  58316  Владимирская обл., Судогодский р-н, д. Лаврово...           62
# 2  58519  Ростовская обл., г. Ростов-на-Дону, ул. 40 Лет...           61
# 3  58526  Ростовская обл., г. Ростов-на-Дону, ул. Нансен...           61
# 4  58253  Ленинский р-н, д. Картамазово, ш. Киевское, 23...           77
#
#    Price92  Price95
# 0    47.04    51.64
# 1    45.10    48.40
# 2     0.00    51.64
# 3     0.00     0.00
# 4    45.50    50.20

# %%
rn.Price95.dtype
# Out:
# dtype('float64')

# %%
rn.shape
# Out:
# (2171, 5)

# %%
rn[rn.Price95 > 0]['Price95'].min()
# Out:
# 2.03

# %%
rn[rn.Price95 > 0]['Price95'].idxmin()
# Out:
# 1974

# %%
rn.iloc[1974]
# Out:
# Azs                                                        63835
# Address        Могилевская обл., Бобруйский р-н, г. Бобруйск,...
# Region_code                                                 1001
# Price92                                                     1.93
# Price95                                                     2.03
# Name: 1974, dtype: object

# %% [markdown]
# # Практическая часть..

# %%
# Добавить в таблицу другие виды топлива
#----- Ваш код здесь ----
from collections import Counter, defaultdict

fuel_type = defaultdict(list)

for station in tqdm(stations):     
    fuel_type['Azs'].append(station['id'])
    for d in station['price']:
        fuel_type[d['type']].append(d['price'])

pd.merge(rn[['Azs', 'Address']], pd.DataFrame(fuel_type), how='inner', on='Azs')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2171.0), HTML(value='')))
#          Azs                                            Address     92  \
# 0      58520  Ростовская обл., Мясниковский р-н, п. Чалтырь,...  47.04
# 1      58316  Владимирская обл., Судогодский р-н, д. Лаврово...  45.10
# 2      58519  Ростовская обл., г. Ростов-на-Дону, ул. 40 Лет...   0.00
# 3      58526  Ростовская обл., г. Ростов-на-Дону, ул. Нансен...   0.00
# 4      58253  Ленинский р-н, д. Картамазово, ш. Киевское, 23...  45.50
# ...      ...                                                ...    ...
# 2166  100513  Томская обл., муниципальный район Асиновский, ...  44.15
# 2167  100515  Ульяновская обл., г. Ульяновск, пр-д 10-й Инже...  44.84
# 2168  100517  Ульяновская обл., г. Ульяновск, пр-т Нариманов...  44.84
# 2169  105501  Хабаровский край, Амурский район, п. Эльбан, у...  48.40
# 2170  113433  Ростовская область г.Ростов-на-Дону, Таганрогс...   0.00
#
#       92_fora     95  95_fora  95_jet   98  98_fora    100  100_pulsar  \
# 0        48.6  51.64    46.54       0  0.0        0   0.00         0.0
# 1         0.0  48.40    48.90       0  0.0        0   0.00         0.0
# 2        48.6  51.64    46.54       0  0.0        0  50.94         0.0
# 3        48.6   0.00    46.54       0  0.0        0  50.94         0.0
# 4         0.0  50.20    51.20       0  0.0        0   0.00        57.8
# ...       ...    ...      ...     ...  ...      ...    ...         ...
# 2166      0.0  47.00     0.00       0  0.0        0   0.00         0.0
# 2167      0.0  48.34     0.00       0  0.0        0   0.00         0.0
# 2168      0.0  48.34     0.00       0  0.0        0   0.00         0.0
# 2169      0.0  50.55     0.00       0  0.0        0   0.00         0.0
# 2170     47.6   0.00    45.54       0  0.0        0  49.94         0.0
#
#       diesel  diesel_fora    gas  methane
# 0       0.00            0   0.00      0.0
# 1      48.50            0   0.00      0.0
# 2       0.00            0   0.00      0.0
# 3       0.00            0   0.00      0.0
# 4      49.20            0   0.00      0.0
# ...      ...          ...    ...      ...
# 2166   52.45            0   0.00      0.0
# 2167   47.99            0  26.99      0.0
# 2168   48.29            0  26.99      0.0
# 2169   55.15            0   0.00      0.0
# 2170    0.00            0   0.00      0.0
#
# [2171 rows x 15 columns]

# %%
# Отделить регионы от адреса АЗС
#----- Ваш код здесь ----

rn = pd.merge(rn[['Azs', 'Address']], pd.DataFrame(fuel_type), how='inner', on='Azs')
rn['regions'] = rn['Address'].apply(lambda x: x.split(',')[0])
rn['Address'] = rn['Address'].apply(lambda x: ','.join(x.split(',')[1:]))
rn
# Out:
#          Azs                                            Address     92  \
# 0      58520   Мясниковский р-н, п. Чалтырь, а/д М23, 9 км, ...  47.04
# 1      58316   Судогодский р-н, д. Лаврово, а/д Р72 (Владими...  45.10
# 2      58519        г. Ростов-на-Дону, ул. 40 Лет Победы, 2Г/51   0.00
# 3      58526                г. Ростов-на-Дону, ул. Нансена, 81А   0.00
# 4      58253          д. Картамазово, ш. Киевское, 23 км, слева  45.50
# ...      ...                                                ...    ...
# 2166  100513   муниципальный район Асиновский, г. Асино, ул....  44.15
# 2167  100515             г. Ульяновск, пр-д 10-й Инженерный, 30  44.84
# 2168  100517                 г. Ульяновск, пр-т Нариманова, 122  44.84
# 2169  105501   Амурский район, п. Эльбан, ул. Заводская, в р...  48.40
# 2170  113433                                 Таганрогская,175 б   0.00
#
#       92_fora     95  95_fora  95_jet   98  98_fora    100  100_pulsar  \
# 0        48.6  51.64    46.54       0  0.0        0   0.00         0.0
# 1         0.0  48.40    48.90       0  0.0        0   0.00         0.0
# 2        48.6  51.64    46.54       0  0.0        0  50.94         0.0
# 3        48.6   0.00    46.54       0  0.0        0  50.94         0.0
# 4         0.0  50.20    51.20       0  0.0        0   0.00        57.8
# ...       ...    ...      ...     ...  ...      ...    ...         ...
# 2166      0.0  47.00     0.00       0  0.0        0   0.00         0.0
# 2167      0.0  48.34     0.00       0  0.0        0   0.00         0.0
# 2168      0.0  48.34     0.00       0  0.0        0   0.00         0.0
# 2169      0.0  50.55     0.00       0  0.0        0   0.00         0.0
# 2170     47.6   0.00    45.54       0  0.0        0  49.94         0.0
#
#       diesel  diesel_fora    gas  methane                              regions
# 0       0.00            0   0.00      0.0                      Ростовская обл.
# 1      48.50            0   0.00      0.0                    Владимирская обл.
# 2       0.00            0   0.00      0.0                      Ростовская обл.
# 3       0.00            0   0.00      0.0                      Ростовская обл.
# 4      49.20            0   0.00      0.0                        Ленинский р-н
# ...      ...          ...    ...      ...                                  ...
# 2166   52.45            0   0.00      0.0                         Томская обл.
# 2167   47.99            0  26.99      0.0                     Ульяновская обл.
# 2168   48.29            0  26.99      0.0                     Ульяновская обл.
# 2169   55.15            0   0.00      0.0                     Хабаровский край
# 2170    0.00            0   0.00      0.0  Ростовская область г.Ростов-на-Дону
#
# [2171 rows x 16 columns]

# %%
# stations[0]

# %%
# Выбрать АЗС из Белоруссии и сохранить в rnbelarus
#----- Ваш код здесь ----
belregions = [ 'Могилевская обл.', 'Витебская обл.',
       'Минская обл.', 'г. Минск', 'Брестская обл.',]
# rn.regions.unique()
rnbelarus = rn[rn.regions.isin(belregions)].Azs.tolist()

# %%
# Пересчитать цены rnbelarus в рубли
#----- Ваш код здесь ----
# curs = 29.12
# rn.loc[rn.Azs.isin(rnbelarus),[92,95,'diesel']] = rn[rn.Azs.isin(rnbelarus)][[92,95,'diesel']].mul(curs)
# rn.loc[rn.Azs.isin(rnbelarus),[92,95,'diesel']]

# %%
prices = rnbelarus.select_dtypes(include=['int64', 'float64']).drop(['Azs'], axis=1).columns
rnbelarus[prices] = rnbelarus[prices] * 29.12

# %%
# Убрать АЗС из Белоруссии из таблциы rn
#----- Ваш код здесь ----
rn = rn[~rn.Azs.isin(rnbelarus)].copy()

# %%
# Расчитать средние цены на топливо по регионам
rn.columns = rn.columns.astype('str')
pd.pivot_table(rn, index='regions', values=, aggfunc='mean' )
# Out:
#                       100  100_pulsar         92  92_fora         95  95_fora  \
# regions
#  Лен. Обл.            0.0         0.0  45.500000      0.0  48.800000     0.00
#  г. Воронеж           0.0         0.0  46.100000     46.5  49.750000     0.00
#  г. Санкт-Петербург   0.0         0.0  45.250000      0.0  48.650000    49.65
# Алтайский край        0.0         0.0  43.561765      0.0  44.881618     0.00
# Амурская обл.         0.0         0.0  47.650000      0.0  50.300000     0.00
# ...                   ...         ...        ...      ...        ...      ...
# г. Сестрорецк         0.0         0.0  45.200000      0.0  48.300000    24.50
# г. Тамбов             0.0         0.0  45.900000     46.3  49.700000     0.00
# п. Репино             0.0         0.0  45.300000      0.0  48.900000     0.00
# п. Стрельна          56.7         0.0  44.900000      0.0  47.800000    48.80
# п. Усть-Славянка      0.0         0.0  44.900000      0.0  48.400000     0.00
#
#                      95_jet         98  98_fora     diesel  diesel_fora  gas  \
# regions
#  Лен. Обл.                0   0.000000        0  50.200000            0  0.0
#  г. Воронеж               0   0.000000        0  48.200000            0  0.0
#  г. Санкт-Петербург       0   0.000000        0  49.700000            0  0.0
# Алтайский край            0  15.485294        0  49.569118            0  0.0
# Амурская обл.             0  11.430000        0  54.950000            0  0.0
# ...                     ...        ...      ...        ...          ...  ...
# г. Сестрорецк             0   0.000000        0  49.950000            0  0.0
# г. Тамбов                 0   0.000000        0  47.900000            0  0.0
# п. Репино                 0   0.000000        0  49.900000            0  0.0
# п. Стрельна               0   0.000000        0  49.000000            0  0.0
# п. Усть-Славянка          0   0.000000        0  49.800000            0  0.0
#
#                      methane
# regions
#  Лен. Обл.               0.0
#  г. Воронеж              0.0
#  г. Санкт-Петербург      0.0
# Алтайский край           0.0
# Амурская обл.            0.0
# ...                      ...
# г. Сестрорецк            0.0
# г. Тамбов                0.0
# п. Репино                0.0
# п. Стрельна              0.0
# п. Усть-Славянка         0.0
#
# [91 rows x 13 columns]

# %%
vcols = ['92', '92_fora', '95', '95_fora', '95_jet', '98', '98_fora', '100',
       '100_pulsar', 'diesel', 'diesel_fora', 'gas', 'methane']

# %%
# Создать директорию regional_prices
#----- Ваш код здесь ----
import os
os.mkdir('regional_prices')

# %%
# Записать в отдельный .csv файл цены для каждого региона. 
# Разделить должен быть знак табуляции sep='\t'
# Название файла записать как название региона, заменив пробел на _
#----- Ваш код здесь ----

# %%
# Выведите содержимое директории в переменную list_of_files
#----- Ваш код здесь ----

# %%
# Создайте словарь regional_prices и заполните его таким образом, чтобы
# ключ был название файла без .csv, а значения - список строк, счиатанных из файла
#----- Ваш код здесь ----

# %%
# Соберите таблицу rnnew из словаря regional_prices
#----- Ваш код здесь ----
